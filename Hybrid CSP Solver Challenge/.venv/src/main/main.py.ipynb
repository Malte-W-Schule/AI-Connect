# %% [markdown]
# Dynamic Constrains resolver for our AI-Connect projekt

# %%
from data_parser import DataParser
import pandas as pd
import os
import re

dataparser = DataParser()

# %%
print(dataparser.houses)
# Out:
# [1, 2, 3, 4, 5]

# %%
from enum import Enum

# Definitions (assumed from earlier examples)
class Name(Enum):
    PETER = 1
    VALERIA = 2

class Color(Enum):
    RED = 1
    BLUE = 2

class House(Enum):
    H1 = 1  # House 1, Position 1
    H2 = 2  # House 2, Position 2
    H3 = 3

# Operator: Equality check
con =  lambda x,y : abs(x-y) == 1
same = lambda x,y : x == y

# Constraint: Name.PETER MUST BE Color.RED
constraint_element = [
    same,       # [0] Operator (==)
    Name,          # [1] Category 1 (Name)
    Name.PETER,    # [2] Variable 1 (PETER)
    Color,         # [3] Category 2 (Color)
    Color.RED      # [4] Variable 2 (RED)
]

constraint_element_2 = [
    same,            # [0] Operator (==)
    Name,           # [1] Category 1 (Name)
    Name.VALERIA,   # [2] Variable 1 (PETER)
    Color,          # [3] Category 2 (Color)
    Color.BLUE      # [4] Variable 2 (RED)
]

constraints = [constraint_element,constraint_element_2]

# %%
CSP_DOMAINS = {
    # House 1 (H1)
    House.H1: {
        Name: [Name.PETER, Name.VALERIA],  # Domain for the Name category
        Color: [Color.RED, Color.BLUE]     # Domain for the Color category
    },

    # House 2 (H2)
    House.H2: {
        Name: [Name.PETER, Name.VALERIA],
        Color: [Color.RED, Color.BLUE]
    }

}

# %%
from Ac3 import AC3

CSP_DOMAINS[House.H2][Color] = [Color.BLUE]
houses = [House.H1, House.H2]

CSP_DOMAINS = dataparser.csp_domains
houses = dataparser.houses
constraints = dataparser.constraints


#solver = AC3(CSP_DOMAINS,constraints,houses)
solver = AC3(dataparser.csp_domains, dataparser.constraints, dataparser.houses)

# %%
#solver.solve()

# %%
#solver.print_domains(CSP_DOMAINS)

# %%
from BacktrackingSolver import BacktrackingSolver
backtracker = BacktrackingSolver(CSP_DOMAINS,constraints,houses)
backtracker.solve(use_ac3_preprocess=True)
solver.print_domains(CSP_DOMAINS)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 from BacktrackingSolver import BacktrackingSolver
#       2 backtracker = BacktrackingSolver(CSP_DOMAINS,constraints,houses)
# ----> 3 backtracker.solve(use_ac3_preprocess=True)
#       4 solver.print_domains(CSP_DOMAINS)
#
# File ~\Documents\GithubProjekteUni\AI-Connect\Hybrid CSP Solver Challenge\.venv\src\main\BacktrackingSolver.py:49, in BacktrackingSolver.solve(self, use_ac3_preprocess)
#      45 """
#      46 Returns solved domains (all singleton lists) or None if no solution.
#      47 """
#      48 if use_ac3_preprocess:
# ---> 49     AC3(self.domains, self.constraints, self.houses).solve()
#      51 if self._has_empty_domain(self.domains):
#      52     return None
#
# File ~\Documents\GithubProjekteUni\AI-Connect\Hybrid CSP Solver Challenge\.venv\src\main\Ac3.py:24, in AC3.solve(self)
#      21 result = False
#      23 for c in self.constraints:
# ---> 24     result = self.revise_domain(self.domain, c, hl, hr)
#      25     if result:
#      26         for h in self.houses:
#
# File ~\Documents\GithubProjekteUni\AI-Connect\Hybrid CSP Solver Challenge\.venv\src\main\Ac3.py:62, in AC3.revise_domain(self, domains, constraint, entity_a_id, entity_b_id)
#      58 new_domain_a = []
#      60 # A. CHECK HOUSE POSITIONS
#      61 # The constraint only applies if the House Operator (e.g., equality) is True
# ---> 62 if house_operator(entity_a_id.value, entity_b_id.value):
#      63
#      64     # B. DOMAIN REDUCTION (Arc Consistency Check)
#      65
#      66     # 3. Revision: Check every value in Domain A (v_a)
#      67     for v_a in domain_a:
#      68         has_support = False
#
# AttributeError: 'int' object has no attribute 'value'
