# %% [markdown]
# Defining the constrains as lambda:

# %%
nextToCon =     lambda x,y : abs(x-y) == 1

notNextToCon =  lambda x,y : abs(x-y) != 1

sameCon =       lambda x,y : x == y

#...

# %% [markdown]
# gives us the option to dynamically use them later withouth hardcoding any

# %%
def useConstraint(nodeleft,noderight,constraint):
    print(f"result:{constraint(nodeleft,noderight)}")

# %%
# basic structure:
house1 = 1
house2 = 2
house3 = 3

attribute = [house1,house2]

# %%
useConstraint(house1,house2,nextToCon)
# Out:
# result:False

# %%
useConstraint(house1,house3,notNextToCon)
# Out:
# result:True

# %% [markdown]
# for constrains which include left and right, for example:

# %%
leftRigtCon =   lambda x,y: x+1 == y

# %% [markdown]
# this means for our queue given we use something like ac3 we had to allways make sure we have the smaler indexed house on the left

# %%
useConstraint(house1,house2,leftRigtCon)    #correct

useConstraint(house2,house1,leftRigtCon)    #incorrect
# Out:
# result:True
# result:False
